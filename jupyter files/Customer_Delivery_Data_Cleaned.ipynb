# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r'.\data\Customer_Delivery_Data.csv')
data
# Out:
#          orderdate articletype originalreqdeliverydate    currentstatus  \
# 0       2022-11-15        ZPLU        21-11-2022 00:00  Order Delivered
# 1       2022-11-16        ZPLU        16-11-2022 00:00  Order Delivered
# 2       2022-11-16        ZPLU        16-11-2022 00:00  Order Delivered
# 3       2022-11-16        ZPLU        16-11-2022 00:00  Order Delivered
# 4       2022-11-16        ZPLU        16-11-2022 00:00  Order Delivered
# ...            ...         ...                     ...              ...
# 232531  2022-11-19        ZPLU        22-11-2022 00:00  Order Delivered
# 232532  2022-11-19        ZPLU        22-11-2022 00:00  Order Delivered
# 232533  2022-11-19        ZPLU        23-11-2022 00:00  Order Delivered
# 232534  2022-11-15        ZPLU        16-11-2022 08:30  Order Delivered
# 232535  2022-11-15        ZPLU        16-11-2022 08:30  Order Delivered
#
#        currentstatustimestamp    sale_timestamp readytopick_timestamp  \
# ...

# %%
data.head()
# Out:
#     orderdate articletype originalreqdeliverydate    currentstatus  \
# 0  2022-11-15        ZPLU        21-11-2022 00:00  Order Delivered
# 1  2022-11-16        ZPLU        16-11-2022 00:00  Order Delivered
# 2  2022-11-16        ZPLU        16-11-2022 00:00  Order Delivered
# 3  2022-11-16        ZPLU        16-11-2022 00:00  Order Delivered
# 4  2022-11-16        ZPLU        16-11-2022 00:00  Order Delivered
#
#   currentstatustimestamp    sale_timestamp readytopick_timestamp  \
# 0       17-11-2022 19:00  15-11-2022 18:39      15-11-2022 20:53
# 1       19-11-2022 13:28  16-11-2022 17:30      16-11-2022 18:25
# 2       21-11-2022 17:34  16-11-2022 17:59      16-11-2022 19:51
# 3       18-11-2022 15:24  16-11-2022 22:22      17-11-2022 02:22
# 4       17-11-2022 18:36  16-11-2022 22:14      16-11-2022 23:20
#
#   readytoship_timestamp  packed_timestamp connecttocarrier_timestamp  ...  \
# 0      16-11-2022 08:15  16-11-2022 08:23           16-11-2022 08:24  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232536 entries, 0 to 232535
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   orderdate                      232536 non-null  object
#  1   articletype                    232536 non-null  object
#  2   originalreqdeliverydate        227834 non-null  object
#  3   currentstatus                  232536 non-null  object
#  4   currentstatustimestamp         232536 non-null  object
#  5   sale_timestamp                 69007 non-null   object
#  6   readytopick_timestamp          52446 non-null   object
#  7   readytoship_timestamp          50458 non-null   object
#  8   packed_timestamp               51825 non-null   object
#  9   connecttocarrier_timestamp     51554 non-null   object
#  10  handedovertocarrier_timestamp  51390 non-null   object
#  11  deliveryinprogress_timestamp   50589 non-null   object
# ...

# %%
data.isna().sum()
# Out:
# orderdate                             0
# articletype                           0
# originalreqdeliverydate            4702
# currentstatus                         0
# currentstatustimestamp                0
# sale_timestamp                   163529
# readytopick_timestamp            180090
# readytoship_timestamp            182078
# packed_timestamp                 180711
# connecttocarrier_timestamp       180982
# handedovertocarrier_timestamp    181146
# deliveryinprogress_timestamp     181947
# outfordelivery_timestamp         180921
# delivered_timestamp                   0
# articlename                       16574
# merchcategorydescription          12481
# merchclassdescription             12481
# merchgroupdescription             12481
# itemdesc                          12181
# shiptozipcode                     12207
# shiptocity                        12491
# shiptostate                       12503
# dtype: int64

# %%
data.dropna(subset=['sale_timestamp'], inplace=True)

# %%
data.dropna(subset=['readytopick_timestamp','readytoship_timestamp','connecttocarrier_timestamp'], inplace=True)

# %%
data.dropna(subset=['handedovertocarrier_timestamp','deliveryinprogress_timestamp'], inplace=True)

# %%
data.dropna(subset=['articlename'], inplace=True)

# %%
data.dropna(subset=['originalreqdeliverydate'], inplace=True)

# %%
data.dropna(subset=['sale_timestamp'], inplace=True)

# %%
data.isna().sum()
# Out:
# orderdate                        0
# articletype                      0
# originalreqdeliverydate          0
# currentstatus                    0
# currentstatustimestamp           0
# sale_timestamp                   0
# readytopick_timestamp            0
# readytoship_timestamp            0
# packed_timestamp                 0
# connecttocarrier_timestamp       0
# handedovertocarrier_timestamp    0
# deliveryinprogress_timestamp     0
# outfordelivery_timestamp         0
# delivered_timestamp              0
# articlename                      0
# merchcategorydescription         0
# merchclassdescription            0
# merchgroupdescription            0
# itemdesc                         0
# shiptozipcode                    0
# shiptocity                       1
# shiptostate                      0
# dtype: int64

# %%
data[data['shiptocity'].isna()]
# Out:
#          orderdate articletype originalreqdeliverydate    currentstatus  \
# 231406  2022-11-17        ZPLU        24-11-2022 00:00  Order Delivered
#
#        currentstatustimestamp    sale_timestamp readytopick_timestamp  \
# 231406       19-11-2022 12:58  17-11-2022 12:40      17-11-2022 13:17
#
#        readytoship_timestamp  packed_timestamp connecttocarrier_timestamp  \
# 231406      17-11-2022 13:40  17-11-2022 14:17           17-11-2022 14:17
#
#         ... outfordelivery_timestamp delivered_timestamp  \
# 231406  ...         19-11-2022 10:27    19-11-2022 12:58
#
#                              articlename merchcategorydescription  \
# 231406  Mi Neckband BT Earphone Pro Blue                Earphones
#
#        merchclassdescription merchgroupdescription  \
# 231406  Earphones/Headphones         Entertainment
#
#                                 itemdesc shiptozipcode shiptocity  \
# 231406  Mi Neckband BT Earphone Pro Blue      505468.0        NaN
#
#            shiptostate
# ...

# %%
# Based on pincode the city is karimnagar
data['shiptocity'].fillna('KARIMNAGAR', inplace=True)

# %%
data.isna().sum()
# Out:
# orderdate                        0
# articletype                      0
# originalreqdeliverydate          0
# currentstatus                    0
# currentstatustimestamp           0
# sale_timestamp                   0
# readytopick_timestamp            0
# readytoship_timestamp            0
# packed_timestamp                 0
# connecttocarrier_timestamp       0
# handedovertocarrier_timestamp    0
# deliveryinprogress_timestamp     0
# outfordelivery_timestamp         0
# delivered_timestamp              0
# articlename                      0
# merchcategorydescription         0
# merchclassdescription            0
# merchgroupdescription            0
# itemdesc                         0
# shiptozipcode                    0
# shiptocity                       0
# shiptostate                      0
# dtype: int64

# %%
date_data = ['orderdate','originalreqdeliverydate','currentstatustimestamp','sale_timestamp','readytopick_timestamp','readytoship_timestamp','packed_timestamp','connecttocarrier_timestamp','handedovertocarrier_timestamp','deliveryinprogress_timestamp','outfordelivery_timestamp','delivered_timestamp']
date_data
# Out:
# ['orderdate',
#  'originalreqdeliverydate',
#  'currentstatustimestamp',
#  'sale_timestamp',
#  'readytopick_timestamp',
#  'readytoship_timestamp',
#  'packed_timestamp',
#  'connecttocarrier_timestamp',
#  'handedovertocarrier_timestamp',
#  'deliveryinprogress_timestamp',
#  'outfordelivery_timestamp',
#  'delivered_timestamp']

# %%
for i in date_data:
    data[i] = pd.to_datetime(data[i])
# Out:
# C:\Users\Devang\AppData\Local\Temp\ipykernel_12012\2888192340.py:2: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data[i] = pd.to_datetime(data[i])
# C:\Users\Devang\AppData\Local\Temp\ipykernel_12012\2888192340.py:2: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data[i] = pd.to_datetime(data[i])
# C:\Users\Devang\AppData\Local\Temp\ipykernel_12012\2888192340.py:2: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data[i] = pd.to_datetime(data[i])
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36984 entries, 0 to 232535
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   orderdate                      36984 non-null  datetime64[ns]
#  1   articletype                    36984 non-null  object
#  2   originalreqdeliverydate        36984 non-null  datetime64[ns]
#  3   currentstatus                  36984 non-null  object
#  4   currentstatustimestamp         36984 non-null  datetime64[ns]
#  5   sale_timestamp                 36984 non-null  datetime64[ns]
#  6   readytopick_timestamp          36984 non-null  datetime64[ns]
#  7   readytoship_timestamp          36984 non-null  datetime64[ns]
#  8   packed_timestamp               36984 non-null  datetime64[ns]
#  9   connecttocarrier_timestamp     36984 non-null  datetime64[ns]
#  10  handedovertocarrier_timestamp  36984 non-null  datetime64[ns]
# ...

# %%
data.to_csv('Customer_Delivery_Data_Cleaned.csv')
